# %%
# !pip install tabula-py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 80.0 MB/s eta 0:00:00
# ...

# %%
# !pip3 install jpype1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas as pd

# Path to the PDF file
pdf_path = "/content/tilok bkn kanreg.pdf"

# Convert PDF to a list of DataFrames
dfs = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# Combine all tables into a single DataFrame (optional)
combined_df = pd.concat(dfs)

# Save the DataFrame to an Excel file
combined_df.to_excel("tilok bkn kanreg.xlsx", index=False)

# %%
import pandas as pd

# %%
kanreg = pd.read_excel("/content/tilok bkn kanreg.xlsx")
kanreg = kanreg.drop(columns=["NIK"])

# %%
kanreg.head()
# Out:
#    NO               LOKASI         NO PESERTA                        NAMA  \
# 0   1   Asrama Haji Kupang  24610020110008088      ACHMAD AGUSTIAN FAREZA
# 1   2  Asrama Haji Mataram  24610020120010688        SRI NAFILAH KHAZINAH
# 2   3  Asrama Haji Mataram  24610020120009120        ANDI ERNA PARAWANSAH
# 3   4  Asrama Haji Mataram  24610020110007040                  HERMANSYAH
# 4   5  Asrama Haji Mataram  24610020120005712  ZSARYTHA MAULIA TIMUR DEWI
#
#                JADWAL  SESI   RUANG  KETERANGAN  . SUMASNA, ST., MUM.
# 0  Jumat, 18 Oct 2024   2.0  Ruang1  Ikut Ujian                   NaN
# 1  Sabtu, 26 Oct 2024   4.0  Ruang1  Ikut Ujian                   NaN
# 2  Sabtu, 26 Oct 2024   4.0  Ruang1  Ikut Ujian                   NaN
# 3  Sabtu, 26 Oct 2024   4.0  Ruang1  Ikut Ujian                   NaN
# 4  Sabtu, 26 Oct 2024   4.0  Ruang1  Ikut Ujian                   NaN

# %%
formasi = pd.read_excel("/content/formasi.xlsx")

# %%
formasi.head()
# Out:
#               noreg                     nama  gender  \
# 0  3005116915770827             ABDUL RAHMAN    Pria
# 1  6100115031402573     ADITYA GUSNA PRANATA    Pria
# 2  6100123609158182        AGISTA SALWADILLA  Wanita
# 3  6100126415693562  AGITA RIFAH NABILAHJAYA  Wanita
# 4  6100116834342041             AGUNG ISMOYO    Pria
#
#                          jabatan                     penempatan  \
# 0  ANALIS KEBIJAKAN AHLI PERTAMA  DINAS KESEHATAN | SEKRETARIAT
# 1  ANALIS KEBIJAKAN AHLI PERTAMA  DINAS KESEHATAN | SEKRETARIAT
# 2  ANALIS KEBIJAKAN AHLI PERTAMA  DINAS KESEHATAN | SEKRETARIAT
# 3  ANALIS KEBIJAKAN AHLI PERTAMA  DINAS KESEHATAN | SEKRETARIAT
# 4  ANALIS KEBIJAKAN AHLI PERTAMA  DINAS KESEHATAN | SEKRETARIAT
#
#                     ket
# 0  Memenuhi Syarat / MS
# 1  Memenuhi Syarat / MS
# 2  Memenuhi Syarat / MS
# 3  Memenuhi Syarat / MS
# 4  Memenuhi Syarat / MS

# %%
mask1 = kanreg["NAMA"].isin(formasi["nama"])

# %%
kanreg[mask1].head()
# Out:
#         NO                         LOKASI         NO PESERTA  \
# 535    536  BKN Pusat Jakarta (Cililitan)  24610020110006528
# 1598  1599  BKN Pusat Jakarta (Cililitan)  24610020110000060
# 1599  1600  BKN Pusat Jakarta (Cililitan)  24610020110001180
# 1600  1601  BKN Pusat Jakarta (Cililitan)  24610020110002648
# 1602  1603  BKN Pusat Jakarta (Cililitan)  24610020110007340
#
#                             NAMA              JADWAL  SESI   RUANG  \
# 535              MUHAMMAD FAISAL  Senin, 04 Nov 2024   1.0  Ruang1
# 1598                ABDUL RAHMAN  Senin, 04 Nov 2024   3.0  Ruang1
# 1599       MUHAMAD RIYAN PRADIKA  Senin, 04 Nov 2024   3.0  Ruang1
# 1600  PRIYANTO ANDREAS PARBAGAON  Senin, 04 Nov 2024   3.0  Ruang1
# 1602                 ILHAM FAUZI  Senin, 04 Nov 2024   3.0  Ruang1
#
#       KETERANGAN  . SUMASNA, ST., MUM.
# 535   Ikut Ujian                   NaN
# 1598  Ikut Ujian                   NaN
# 1599  Ikut Ujian                   NaN
# ...

# %%
# Path to the PDF file
pdf_path = "/content/tilok arcamanik.pdf"

# Convert PDF to a list of DataFrames
dfs = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# Combine all tables into a single DataFrame (optional)
combined_df = pd.concat(dfs)

# Save the DataFrame to an Excel file
combined_df.to_excel("tilok arcamanik.xlsx", index=False)

# %%
arcamanik = pd.read_excel("/content/tilok arcamanik.xlsx")
arcamanik = arcamanik.drop(columns=["NIK"])
arcamanik.head()
# Out:
#    NO                               LOKASI         NO PESERTA  \
# 0   1  Gedung Youth Center Sport Arcamanik  24610020110000640
# 1   2  Gedung Youth Center Sport Arcamanik  24610020110001152
# 2   3  Gedung Youth Center Sport Arcamanik  24610020110001552
# 3   4  Gedung Youth Center Sport Arcamanik  24610020110001568
# 4   5  Gedung Youth Center Sport Arcamanik  24610020110002400
#
#                            NAMA              JADWAL  SESI   RUANG  KETERANGAN
# 0       ALTHAAF MIQDAD SCHOLLES  Senin, 04 Nov 2024   2.0  Ruang1  Ikut Ujian
# 1  INDIKA WILDY RAMADHAN ANDIKO  Senin, 04 Nov 2024   2.0  Ruang1  Ikut Ujian
# 2             BANYU PRIMA DARIS  Senin, 04 Nov 2024   2.0  Ruang1  Ikut Ujian
# 3       R. MUHAMMAD REZKY KAMIL  Senin, 04 Nov 2024   2.0  Ruang1  Ikut Ujian
# 4       MUHAMAD RIZKI ADITYA AF  Senin, 04 Nov 2024   2.0  Ruang1  Ikut Ujian

# %%
mask2 = arcamanik["NAMA"].isin(formasi["nama"])

# %%
arcamanik[mask2].head()
# Out:
#         NO                               LOKASI         NO PESERTA  \
# 875    876  Gedung Youth Center Sport Arcamanik  24610020120000740
# 5882  5883  Gedung Youth Center Sport Arcamanik  24610020110000008
# 5883  5884  Gedung Youth Center Sport Arcamanik  24610020110000120
# 5884  5885  Gedung Youth Center Sport Arcamanik  24610020110000320
# 5885  5886  Gedung Youth Center Sport Arcamanik  24610020110000408
#
#                            NAMA               JADWAL  SESI   RUANG  KETERANGAN
# 875                DEWI LESTARI  Selasa, 05 Nov 2024   1.0  Ruang1  Ikut Ujian
# 5882  RAKHI NAUFAL CHAERULZAMAN   Jumat, 08 Nov 2024   1.0  Ruang1  Ikut Ujian
# 5883      DIKDIK SEPTIA PERMANA   Jumat, 08 Nov 2024   1.0  Ruang1  Ikut Ujian
# 5884              PATRA NUGRAHA   Jumat, 08 Nov 2024   1.0  Ruang1  Ikut Ujian
# 5885                HENDERAYANA   Jumat, 08 Nov 2024   1.0  Ruang1  Ikut Ujian

# %%
analis_kebijakan = pd.concat([kanreg[mask1], arcamanik[mask2]])

analis_kebijakan.to_excel("analis kebijakan.xlsx", index=False)
