# %%
pip install tabula-py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 1.2 MB/s eta 0:00:00
# ...

# %%
# !pip3 install jpype1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas as pd

# Path to the PDF file
pdf_path = "/content/adm.pdf"

# Convert PDF to a list of DataFrames
dfs = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# Combine all tables into a single DataFrame (optional)
combined_df = pd.concat(dfs)

# Save the DataFrame to an Excel file
combined_df.to_excel("output_file.xlsx", index=False)

# %%
import pandas as pd

# %%
df = pd.read_excel('adm.xlsx')

# %%
df.head()
# Out:
#                    nama  gender                                       jabatan  \
# 0   A AZFIKAR NUR AZHAR    Pria                   PENGELOLA LAYANAN KESEHATAN
# 1  A FAISYAL RACHMAN JP    Pria  PENGELOLA PENGADAAN BARANG/JASA AHLI PERTAMA
# 2           A HIDAYANTI  Wanita               PENATA KELOLA LAYANAN KESEHATAN
# 3             A HIDAYAT    Pria                            ARSIPARIS TERAMPIL
# 4        A JUAN SAPUTRA    Pria                        PERENCANA AHLI PERTAMA
#
#                                           penempatan                   ket
# 0     DINAS KESEHATAN | BIDANG SUMBER DAYA KESEHATAN  Memenuhi Syarat / MS
# 1  SEKRETARIAT DAERAH | ASISTEN PEREKONOMIAN DAN ...  Memenuhi Syarat / MS
# 2       DINAS KESEHATAN | BIDANG PELAYANAN KESEHATAN  Memenuhi Syarat / MS
# 3  DINAS ENERGI DAN SUMBER DAYA MINERAL | SEKRETA...  Memenuhi Syarat / MS
# 4  DINAS BINA MARGA DAN PENATAAN RUANG | SEKRETARIAT  Memenuhi Syarat / MS

# %%
formasi = df[(df['jabatan'] == 'ANALIS KEBIJAKAN AHLI PERTAMA') & (df['penempatan'] == 'DINAS KESEHATAN | SEKRETARIAT') & (df['ket'] == 'Memenuhi Syarat / MS')]

# %%
formasi.head()
# Out:
#                         nama  gender                        jabatan  \
# 84              ABDUL RAHMAN    Pria  ANALIS KEBIJAKAN AHLI PERTAMA
# 440     ADITYA GUSNA PRANATA    Pria  ANALIS KEBIJAKAN AHLI PERTAMA
# 625        AGISTA SALWADILLA  Wanita  ANALIS KEBIJAKAN AHLI PERTAMA
# 629  AGITA RIFAH NABILAHJAYA  Wanita  ANALIS KEBIJAKAN AHLI PERTAMA
# 686             AGUNG ISMOYO    Pria  ANALIS KEBIJAKAN AHLI PERTAMA
#
#                         penempatan                   ket
# 84   DINAS KESEHATAN | SEKRETARIAT  Memenuhi Syarat / MS
# 440  DINAS KESEHATAN | SEKRETARIAT  Memenuhi Syarat / MS
# 625  DINAS KESEHATAN | SEKRETARIAT  Memenuhi Syarat / MS
# 629  DINAS KESEHATAN | SEKRETARIAT  Memenuhi Syarat / MS
# 686  DINAS KESEHATAN | SEKRETARIAT  Memenuhi Syarat / MS

# %%
formasi.to_excel('formasi.xlsx')

# %%
formasi['gender'].value_counts()
# Out:
# gender
# Wanita    137
# Pria       84
# Name: count, dtype: int64
