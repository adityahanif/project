# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_excel("/content/Kelas Disiplin Feb 2025.xlsx")
df2 = pd.read_excel("/content/Piket Kelas Disiplin Feb 2025.xlsx")

# %%
df1.head()
# Out:
#       kelas     tanggal                           guru         keaktifan  \
# 0  10 (TQM)  21/01/2025      Ust. Asep Saepudin, M.Pd.       4. Antusias
# 1        9A  22/01/2025          Ust. Risnawan Q, SHI.  3. Memperhatikan
# 2        9B  22/01/2025          Ust. Risnawan Q, SHI.  3. Memperhatikan
# 3        9C  24/01/2025  Usth. Tysa Nursafa Riyandiani  3. Memperhatikan
# 4        8C  24/01/2025  Usth. Tysa Nursafa Riyandiani  3. Memperhatikan
#
#                  izin_kbm                        siswa_masuk_kelas guru_doa  \
# 0  3. Tidak Ada yang Izin  3. Siswa Sudah di Kelas Saat Guru Masuk   2. Iya
# 1         2. Sedikit Izin  3. Siswa Sudah di Kelas Saat Guru Masuk   2. Iya
# 2         2. Sedikit Izin  3. Siswa Sudah di Kelas Saat Guru Masuk   2. Iya
# 3  3. Tidak Ada yang Izin  3. Siswa Sudah di Kelas Saat Guru Masuk   2. Iya
# 4         2. Sedikit Izin  3. Siswa Sudah di Kelas Saat Guru Masuk   2. Iya
#
#   murid_doa                  respon_papan_tulis  \
# 0    2. Iya   3. Siswa Membersihkan Papan Tulis
# 1    2. Iya   3. Siswa Membersihkan Papan Tulis
# 2    2. Iya   3. Siswa Membersihkan Papan Tulis
# 3    2. Iya  2. Siswa Membersihkan Saat Disuruh
# 4    2. Iya  2. Siswa Membersihkan Saat Disuruh
#
#                           respon_meja_kursi  \
# 0  3. Siswa Mandiri Merapikan Meja Kursinya
# 1  3. Siswa Mandiri Merapikan Meja Kursinya
# 2  3. Siswa Mandiri Merapikan Meja Kursinya
# 3           2. Siswa Merapikan Saat Disuruh
# 4           2. Siswa Merapikan Saat Disuruh
#
#                      respon_membangunkan          kelengkapan_sepatu  \
# 0             1. Membiarkan yang Ngantuk  2. Melepas Sepatu di Kelas
# 1  2. Sesekali Membangunkan yang Ngantuk           3. Memakai Sepatu
# 2             1. Membiarkan yang Ngantuk           3. Memakai Sepatu
# 3  2. Sesekali Membangunkan yang Ngantuk           3. Memakai Sepatu
# 4  2. Sesekali Membangunkan yang Ngantuk  2. Melepas Sepatu di Kelas
#
#                         respon_menyalami_guru
# 0   3. Siswa Menyalami Guru Saat KBM Berakhir
# 1  1. Siswa Tidak Menyalami Saat KBM Berakhir
# 2   3. Siswa Menyalami Guru Saat KBM Berakhir
# 3  1. Siswa Tidak Menyalami Saat KBM Berakhir
# 4  1. Siswa Tidak Menyalami Saat KBM Berakhir

# %%
df2.head()
# Out:
#   kelas    tanggal                guru        kebersihan  \
# 0    7A 2025-01-29  Risnawan Q, S.H.I.  2. Kurang Bersih
# 1    7B 2025-01-29  Risnawan Q, S.H.I.  2. Kurang Bersih
# 2    8A 2025-01-29  Risnawan Q, S.H.I.  2. Kurang Bersih
# 3    8B 2025-01-29  Risnawan Q, S.H.I.  2. Kurang Bersih
# 4    9A 2025-01-29  Risnawan Q, S.H.I.          1. Kotor
#
#   respon_penanganan_sampah kelengkapan_inventaris        kerapian  \
# 0           2. Kurang Baik       1. Tidak Lengkap   1. Tidak Rapi
# 1           2. Kurang Baik      2. Kurang Lengkap  2. Kurang Rapi
# 2           2. Kurang Baik      2. Kurang Lengkap  2. Kurang Rapi
# 3           2. Kurang Baik      2. Kurang Lengkap  2. Kurang Rapi
# 4           2. Kurang Baik             3. Lengkap         3. Rapi
#
#   kelengkapan_seragam  kerapian_akhir
# 0          3. Lengkap  2. Kurang Rapi
# 1          3. Lengkap         3. Rapi
# 2          3. Lengkap         3. Rapi
# 3          3. Lengkap         3. Rapi
# 4   2. Kurang Lengkap  2. Kurang Rapi

# %%
df1['respon_menyalami_guru'].fillna(df1['respon_menyalami_guru'].mode()[0], inplace=True)

# %%
def hapus_setelah_titik(str):
    return str.split(".")[0]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   kelas                  128 non-null    object
#  1   tanggal                128 non-null    object
#  2   guru                   128 non-null    object
#  3   keaktifan              128 non-null    object
#  4   izin_kbm               128 non-null    object
#  5   siswa_masuk_kelas      128 non-null    object
#  6   guru_doa               128 non-null    object
#  7   murid_doa              128 non-null    object
#  8   respon_papan_tulis     128 non-null    object
#  9   respon_meja_kursi      128 non-null    object
#  10  respon_membangunkan    128 non-null    object
#  11  kelengkapan_sepatu     128 non-null    object
#  12  respon_menyalami_guru  128 non-null    object
# dtypes: object(13)
# memory usage: 13.1+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   kelas                     39 non-null     object
#  1   tanggal                   39 non-null     datetime64[ns]
#  2   guru                      39 non-null     object
#  3   kebersihan                39 non-null     object
#  4   respon_penanganan_sampah  39 non-null     object
#  5   kelengkapan_inventaris    39 non-null     object
#  6   kerapian                  39 non-null     object
#  7   kelengkapan_seragam       39 non-null     object
#  8   kerapian_akhir            39 non-null     object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 2.9+ KB

# %%
for m in range (3, 13):
  df1[df1.columns[m]] = df1[df1.columns[m]].apply(hapus_setelah_titik)

# %%
for n in range (3, 9):
  df2[df2.columns[n]] = df2[df2.columns[n]].apply(hapus_setelah_titik)

# %%
df1.columns
# Out:
# Index(['kelas', 'tanggal', 'guru', 'keaktifan', 'izin_kbm',
#        'siswa_masuk_kelas', 'guru_doa', 'murid_doa', 'respon_papan_tulis',
#        'respon_meja_kursi', 'respon_membangunkan', 'kelengkapan_sepatu',
#        'respon_menyalami_guru'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['kelas', 'tanggal', 'guru', 'kebersihan', 'respon_penanganan_sampah',
#        'kelengkapan_inventaris', 'kerapian', 'kelengkapan_seragam',
#        'kerapian_akhir'],
#       dtype='object')

# %%
df1.head()
# Out:
#       kelas     tanggal                           guru keaktifan izin_kbm  \
# 0  10 (TQM)  21/01/2025      Ust. Asep Saepudin, M.Pd.       100        3
# 1        9A  22/01/2025          Ust. Risnawan Q, SHI.        75        2
# 2        9B  22/01/2025          Ust. Risnawan Q, SHI.        75        2
# 3        9C  24/01/2025  Usth. Tysa Nursafa Riyandiani        75        3
# 4        8C  24/01/2025  Usth. Tysa Nursafa Riyandiani        75        2
#
#   siswa_masuk_kelas guru_doa murid_doa respon_papan_tulis respon_meja_kursi  \
# 0                 3        2         2                  3                 3
# 1                 3        2         2                  3                 3
# 2                 3        2         2                  3                 3
# 3                 3        2         2                  2                 2
# 4                 3        2         2                  2                 2
#
#   respon_membangunkan kelengkapan_sepatu respon_menyalami_guru
# 0                   1                  2                     3
# 1                   2                  3                     1
# 2                   1                  3                     3
# 3                   2                  3                     1
# 4                   2                  2                     1

# %%
df2.head(5)
# Out:
#   kelas    tanggal                guru kebersihan respon_penanganan_sampah  \
# 0    7A 2025-01-29  Risnawan Q, S.H.I.          2                        2
# 1    7B 2025-01-29  Risnawan Q, S.H.I.          2                        2
# 2    8A 2025-01-29  Risnawan Q, S.H.I.          2                        2
# 3    8B 2025-01-29  Risnawan Q, S.H.I.          2                        2
# 4    9A 2025-01-29  Risnawan Q, S.H.I.          1                        2
#
#   kelengkapan_inventaris kerapian kelengkapan_seragam kerapian_akhir
# 0                      1        1                   3              2
# 1                      2        2                   3              3
# 2                      2        2                   3              3
# 3                      2        2                   3              3
# 4                      3        3                   2              2

# %%
df1["keaktifan"].replace({"1": "25", "2": "50", "3": "75", "4": "100"}, inplace=True)

# %%
kolom_doa = ['guru_doa', 'murid_doa']

for x in kolom_doa:
  df1[x].replace({"1": "50", "2": "100"}, inplace=True)

# %%
kolom1 = ['izin_kbm',
       'siswa_masuk_kelas', 'respon_papan_tulis',
       'respon_meja_kursi', 'respon_membangunkan', 'respon_menyalami_guru',
       'kelengkapan_sepatu']

for x in kolom1:
  df1[x].replace({"1": "33.333", "2": "66.666", "3": "99.999"}, inplace=True)

# %%
kolom2 = ['kebersihan', 'respon_penanganan_sampah',
       'kelengkapan_inventaris', 'kerapian', 'kelengkapan_seragam',
       'kerapian_akhir']

for x in kolom2:
  df2[x].replace({"1": "33.333", "2": "66.666", "3": "99.999"}, inplace=True)

# %%
for y in range (3, 13):
  df1[df1.columns[y]] = df1[df1.columns[y]].astype(float)

for y in range (3, 9):
  df2[df2.columns[y]] = df2[df2.columns[y]].astype(float)

# %%
df1.drop(columns=(['tanggal', 'guru']), inplace=True)
df2.drop(columns=(['tanggal', 'guru']), inplace=True)

# %%
agg1 = df1.groupby(['kelas']).mean()
agg1.head(10)
# Out:
#           keaktifan   izin_kbm  siswa_masuk_kelas  guru_doa   murid_doa  \
# kelas
# 10 (TQM)  87.500000  99.999000          99.999000     100.0  100.000000
# 7A        75.000000  76.665900          89.999100     100.0  100.000000
# 7B        75.000000  80.554750          97.221250     100.0   95.833333
# 7C        81.250000  83.332500          99.999000     100.0  100.000000
# 8A        83.333333  80.554750          88.888000     100.0  100.000000
# 8B        83.333333  86.110250          94.443500     100.0  100.000000
# 8C        81.818182  84.847636          99.999000     100.0  100.000000
# 9A        72.619048  73.015143          90.475286     100.0  100.000000
# 9B        82.500000  76.665900          91.665750     100.0   97.500000
# 9C        87.500000  83.332500          95.832375     100.0  100.000000
#
#           respon_papan_tulis  respon_meja_kursi  respon_membangunkan  \
# kelas
# 10 (TQM)           99.999000          99.999000            66.666000
# 7A                 83.332500          93.332400            73.332600
# 7B                 86.110250          94.443500            80.554750
# 7C                 91.665750          83.332500            70.832625
# 8A                 97.221250          99.999000            63.888250
# 8B                 95.832375          94.443500            77.777000
# 8C                 90.908182          96.968727            72.726545
# 9A                 95.237143          92.062571            61.904143
# 9B                 83.332500          93.332400            64.999350
# 9C                 83.332500          83.332500            58.332750
#
#           kelengkapan_sepatu  respon_menyalami_guru
# kelas
# 10 (TQM)           66.666000              99.999000
# 7A                 99.999000              99.999000
# 7B                 94.443500              99.999000
# 7C                 70.832625              95.832375
# 8A                 94.443500              88.888000
# 8B                 90.276875              88.888000
# 8C                 72.726545              78.787091
# 9A                 88.888000              63.491429
# 9B                 88.332450              84.999150
# 9C                 99.999000              58.332750

# %%
agg2 = df2.groupby(['kelas']).mean()
agg2.head(10)
# Out:
#        kebersihan  respon_penanganan_sampah  kelengkapan_inventaris  kerapian  \
# kelas
# 7A        93.3324                   86.6658                 59.9994   66.6660
# 7B        93.3324                   93.3324                 66.6660   73.3326
# 7C        99.9990                   88.8880                 99.9990   99.9990
# 8A        86.6658                   73.3326                 73.3326   73.3326
# 8B        79.9992                   86.6658                 73.3326   73.3326
# 8C        99.9990                   99.9990                 99.9990   77.7770
# 9A        86.6658                   93.3324                 79.9992   86.6658
# 9B        86.6658                   86.6658                 86.6658   73.3326
# 9C        99.9990                   99.9990                 99.9990   99.9990
#
#        kelengkapan_seragam  kerapian_akhir
# kelas
# 7A                 99.9990         93.3324
# 7B                 99.9990         99.9990
# 7C                 99.9990         99.9990
# 8A                 99.9990         99.9990
# 8B                 93.3324         93.3324
# 8C                 99.9990         99.9990
# 9A                 86.6658         93.3324
# 9B                 93.3324         99.9990
# 9C                 99.9990         99.9990

# %%
agg2_mean = agg2.mean()

# %%
agg1.index
# Out:
# Index(['10 (TQM)', '7A', '7B', '7C', '8A', '8B', '8C', '9A', '9B', '9C'], dtype='object', name='kelas')

# %%
#Karena tidak ada data kebersihan untuk kelas TQM, maka data akan diisi dengan memasukkan rata2 keseluruhan

new_TQM = pd.DataFrame([agg2_mean], index=['10 (TQM)'])
new_TQM
# Out:
#           kebersihan  respon_penanganan_sampah  kelengkapan_inventaris  \
# 10 (TQM)   91.850933                 89.875644                 82.2214
#
#            kerapian  kelengkapan_seragam  kerapian_akhir
# 10 (TQM)  80.493022            97.036067         97.7768

# %%
#Menambahkan hasil rata-rata ke dalam dataframe

agg2_new = pd.concat([new_TQM, agg2])
agg2_new
# Out:
#           kebersihan  respon_penanganan_sampah  kelengkapan_inventaris  \
# 10 (TQM)   91.850933                 89.875644                 82.2214
# 7A         93.332400                 86.665800                 59.9994
# 7B         93.332400                 93.332400                 66.6660
# 7C         99.999000                 88.888000                 99.9990
# 8A         86.665800                 73.332600                 73.3326
# 8B         79.999200                 86.665800                 73.3326
# 8C         99.999000                 99.999000                 99.9990
# 9A         86.665800                 93.332400                 79.9992
# 9B         86.665800                 86.665800                 86.6658
# 9C         99.999000                 99.999000                 99.9990
#
#            kerapian  kelengkapan_seragam  kerapian_akhir
# 10 (TQM)  80.493022            97.036067         97.7768
# 7A        66.666000            99.999000         93.3324
# 7B        73.332600            99.999000         99.9990
# 7C        99.999000            99.999000         99.9990
# 8A        73.332600            99.999000         99.9990
# 8B        73.332600            93.332400         93.3324
# 8C        77.777000            99.999000         99.9990
# 9A        86.665800            86.665800         93.3324
# 9B        73.332600            93.332400         99.9990
# 9C        99.999000            99.999000         99.9990

# %%
#gabungkan kolom untuk kelas/baris yang sama

df = pd.concat([agg1, agg2_new], axis=1)
df
# Out:
#           keaktifan   izin_kbm  siswa_masuk_kelas  guru_doa   murid_doa  \
# 10 (TQM)  87.500000  99.999000          99.999000     100.0  100.000000
# 7A        75.000000  76.665900          89.999100     100.0  100.000000
# 7B        75.000000  80.554750          97.221250     100.0   95.833333
# 7C        81.250000  83.332500          99.999000     100.0  100.000000
# 8A        83.333333  80.554750          88.888000     100.0  100.000000
# 8B        83.333333  86.110250          94.443500     100.0  100.000000
# 8C        81.818182  84.847636          99.999000     100.0  100.000000
# 9A        72.619048  73.015143          90.475286     100.0  100.000000
# 9B        82.500000  76.665900          91.665750     100.0   97.500000
# 9C        87.500000  83.332500          95.832375     100.0  100.000000
#
#           respon_papan_tulis  respon_meja_kursi  respon_membangunkan  \
# 10 (TQM)           99.999000          99.999000            66.666000
# 7A                 83.332500          93.332400            73.332600
# 7B                 86.110250          94.443500            80.554750
# 7C                 91.665750          83.332500            70.832625
# 8A                 97.221250          99.999000            63.888250
# 8B                 95.832375          94.443500            77.777000
# 8C                 90.908182          96.968727            72.726545
# 9A                 95.237143          92.062571            61.904143
# 9B                 83.332500          93.332400            64.999350
# 9C                 83.332500          83.332500            58.332750
#
#           kelengkapan_sepatu  respon_menyalami_guru  kebersihan  \
# 10 (TQM)           66.666000              99.999000   91.850933
# 7A                 99.999000              99.999000   93.332400
# 7B                 94.443500              99.999000   93.332400
# 7C                 70.832625              95.832375   99.999000
# 8A                 94.443500              88.888000   86.665800
# 8B                 90.276875              88.888000   79.999200
# 8C                 72.726545              78.787091   99.999000
# 9A                 88.888000              63.491429   86.665800
# 9B                 88.332450              84.999150   86.665800
# 9C                 99.999000              58.332750   99.999000
#
#           respon_penanganan_sampah  kelengkapan_inventaris   kerapian  \
# 10 (TQM)                 89.875644                 82.2214  80.493022
# 7A                       86.665800                 59.9994  66.666000
# 7B                       93.332400                 66.6660  73.332600
# 7C                       88.888000                 99.9990  99.999000
# 8A                       73.332600                 73.3326  73.332600
# 8B                       86.665800                 73.3326  73.332600
# 8C                       99.999000                 99.9990  77.777000
# 9A                       93.332400                 79.9992  86.665800
# 9B                       86.665800                 86.6658  73.332600
# 9C                       99.999000                 99.9990  99.999000
#
#           kelengkapan_seragam  kerapian_akhir
# 10 (TQM)            97.036067         97.7768
# 7A                  99.999000         93.3324
# 7B                  99.999000         99.9990
# 7C                  99.999000         99.9990
# 8A                  99.999000         99.9990
# 8B                  93.332400         93.3324
# 8C                  99.999000         99.9990
# 9A                  86.665800         93.3324
# 9B                  93.332400         99.9990
# 9C                  99.999000         99.9990

# %%
#kelompokkan setiap kategori ke dalam kategori utama
df["kebersihan_total"] = df["kebersihan"]
df["keaktifan_total"] = (df["keaktifan"] + df["izin_kbm"] + df["siswa_masuk_kelas"])/3
df["berdoa"] = (df["guru_doa"] + df["murid_doa"])/2
df["responsif_total"] = (df["respon_papan_tulis"] + df["respon_meja_kursi"] + df["respon_membangunkan"] + df["respon_menyalami_guru"] + df["respon_penanganan_sampah"])/5
df["kerapian_total"] = (df["kerapian"] + df["kerapian_akhir"])/2
df["kelengkapan_total"] = (df["kelengkapan_sepatu"] + df["kelengkapan_inventaris"] + df["kelengkapan_seragam"])/3

# %%
#buat dataframe baru berdasarkan kategori utama
df_final = df[['kebersihan_total',
       'keaktifan_total', 'berdoa', 'responsif_total', 'kerapian_total',
       'kelengkapan_total']]

df_final.head(10)
# Out:
#           kebersihan_total  keaktifan_total      berdoa  responsif_total  \
# 10 (TQM)         91.850933        95.832667  100.000000        91.307729
# 7A               93.332400        80.555000  100.000000        87.332460
# 7B               93.332400        84.258667   97.916667        90.887980
# 7C               99.999000        88.193833  100.000000        86.110250
# 8A               86.665800        84.258694  100.000000        84.665820
# 8B               79.999200        87.962361  100.000000        88.721335
# 8C               99.999000        88.888273  100.000000        87.877909
# 9A               86.665800        78.703159  100.000000        81.205537
# 9B               86.665800        83.610550   98.750000        82.665840
# 9C               99.999000        88.888292  100.000000        76.665900
#
#           kerapian_total  kelengkapan_total
# 10 (TQM)       89.134911          81.974489
# 7A             79.999200          86.665800
# 7B             86.665800          87.036167
# 7C             99.999000          90.276875
# 8A             86.665800          89.258367
# 8B             83.332500          85.647292
# 8C             88.888000          90.908182
# 9A             89.999100          85.184333
# 9B             86.665800          89.443550
# 9C             99.999000          99.999000

# %%
#menambahkan kolom total berdasarkan rata2 keseluruhan aspek/kategori
df_final["total_sum"] = df_final.sum(axis=1)
df_final["total_avg"] = df_final.mean(axis=1)
df_final.head(10)
# Out:
#           kebersihan_total  keaktifan_total      berdoa  responsif_total  \
# 10 (TQM)         91.850933        95.832667  100.000000        91.307729
# 7A               93.332400        80.555000  100.000000        87.332460
# 7B               93.332400        84.258667   97.916667        90.887980
# 7C               99.999000        88.193833  100.000000        86.110250
# 8A               86.665800        84.258694  100.000000        84.665820
# 8B               79.999200        87.962361  100.000000        88.721335
# 8C               99.999000        88.888273  100.000000        87.877909
# 9A               86.665800        78.703159  100.000000        81.205537
# 9B               86.665800        83.610550   98.750000        82.665840
# 9C               99.999000        88.888292  100.000000        76.665900
#
#           kerapian_total  kelengkapan_total   total_avg   total_sum
# 10 (TQM)       89.134911          81.974489  160.446046  641.784184
# 7A             79.999200          86.665800  153.966417  615.865670
# 7B             86.665800          87.036167  157.528490  630.113960
# 7C             99.999000          90.276875  164.668863  658.675451
# 8A             86.665800          89.258367  155.025057  620.100228
# 8B             83.332500          85.647292  153.318284  613.273136
# 8C             88.888000          90.908182  162.330398  649.321591
# 9A             89.999100          85.184333  152.179396  608.717584
# 9B             86.665800          89.443550  153.942116  615.768463
# 9C             99.999000          99.999000  164.952431  659.809724

# %%
#sortir berdasarkan total tertinggi
df_final.sort_values(by="total_avg", ascending=False).round(3)
# Out:
#           kebersihan_total  keaktifan_total   berdoa  responsif_total  \
# 9C                  99.999           88.888  100.000           76.666
# 7C                  99.999           88.194  100.000           86.110
# 8C                  99.999           88.888  100.000           87.878
# 10 (TQM)            91.851           95.833  100.000           91.308
# 7B                  93.332           84.259   97.917           90.888
# 8A                  86.666           84.259  100.000           84.666
# 7A                  93.332           80.555  100.000           87.332
# 9B                  86.666           83.611   98.750           82.666
# 8B                  79.999           87.962  100.000           88.721
# 9A                  86.666           78.703  100.000           81.206
#
#           kerapian_total  kelengkapan_total  total_avg  total_sum
# 9C                99.999             99.999    164.952    659.810
# 7C                99.999             90.277    164.669    658.675
# 8C                88.888             90.908    162.330    649.322
# 10 (TQM)          89.135             81.974    160.446    641.784
# 7B                86.666             87.036    157.528    630.114
# 8A                86.666             89.258    155.025    620.100
# 7A                79.999             86.666    153.966    615.866
# 9B                86.666             89.444    153.942    615.768
# 8B                83.332             85.647    153.318    613.273
# 9A                89.999             85.184    152.179    608.718

# %%
sns.barplot(data=df_final['total_avg'].sort_values(ascending=False), orient='h')
plt.title('Grafik Lomba Kelas Disiplin Februari 2025 [Keseluruhan]')
plt.xlabel('Rata-Rata Akhir')
plt.ylabel('Kelas');

# %%
sns.barplot(data=df_final['keaktifan_total'].sort_values(ascending=False), orient='h')
plt.title('Grafik Lomba Kelas Disiplin Februari 2025 [Keaktifan]')
plt.xlabel('Rata-Rata Akhir')
plt.ylabel('Kelas');

# %%
sns.barplot(data=df_final['kebersihan_total'].sort_values(ascending=False), orient='h')
plt.title('Grafik Lomba Kelas Disiplin Februari 2025 [Kebersihan]')
plt.xlabel('Rata-Rata Akhir')
plt.ylabel('Kelas');

# %%
sns.barplot(data=df_final['kerapian_total'].sort_values(ascending=False), orient='h')
plt.title('Grafik Lomba Kelas Disiplin Februari 2025 [Kerapian]')
plt.xlabel('Rata-Rata Akhir')
plt.ylabel('Kelas');
