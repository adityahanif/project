# %%
# !pip install tabula-py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 78.4 MB/s eta 0:00:00
# ...

# %%
# !pip3 install jpype1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas as pd

# Path to the PDF file
pdf_path = "/content/pasca sanggah.pdf"

# Convert PDF to a list of DataFrames
dfs = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# Combine all tables into a single DataFrame (optional)
combined_df = pd.concat(dfs)

# Save the DataFrame to an Excel file
combined_df.to_excel("pasca sanggah exc.xlsx", index=False)

# %%
df = pd.read_excel("/content/pasca sanggah exc.xlsx")
df.head()
# Out:
#    NO  NOMOR REGISTRASI          NAMA PELAMAR JENIS\rKELAMIN  \
# 0   1  6116111848928696   A AZFIKAR NUR AZHAR           Pria
# 1   2  6100118716575747  A FAISYAL RACHMAN JP           Pria
# 2   3  6100124600583863           A HIDAYANTI         Wanita
# 3   4  6100113674366924     A MAULANA MUKHSIN           Pria
# 4   5  6100110392034262     A MULQI FADILAH A           Pria
#
#                            JABATAN YANG DILAMAR  \
# 0                   PENGELOLA LAYANAN KESEHATAN
# 1  PENGELOLA PENGADAAN BARANG/JASA AHLI PERTAMA
# 2               PENATA KELOLA LAYANAN KESEHATAN
# 3                        PERENCANA AHLI PERTAMA
# 4     PENGENDALI DAMPAK LINGKUNGAN AHLI PERTAMA
#
#                         UNIT PENEMPATAN YANG DILAMAR  \
# 0  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 1  PEMERINTAH DAERAH PROVINSI JAWA BARAT | SEKRET...
# 2  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 3  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# ...

# %%
df.columns
# Out:
# Index(['NO', 'NOMOR REGISTRASI', 'NAMA PELAMAR', 'JENIS\rKELAMIN',
#        'JABATAN YANG DILAMAR', 'UNIT PENEMPATAN YANG DILAMAR', 'KETERANGAN',
#        '. SUMASNA, ST., MUM.'],
#       dtype='object')

# %%
df = df.drop(columns=[". SUMASNA, ST., MUM."])

# %%
df.head()
# Out:
#    NO  NOMOR REGISTRASI          NAMA PELAMAR JENIS\rKELAMIN  \
# 0   1  6116111848928696   A AZFIKAR NUR AZHAR           Pria
# 1   2  6100118716575747  A FAISYAL RACHMAN JP           Pria
# 2   3  6100124600583863           A HIDAYANTI         Wanita
# 3   4  6100113674366924     A MAULANA MUKHSIN           Pria
# 4   5  6100110392034262     A MULQI FADILAH A           Pria
#
#                            JABATAN YANG DILAMAR  \
# 0                   PENGELOLA LAYANAN KESEHATAN
# 1  PENGELOLA PENGADAAN BARANG/JASA AHLI PERTAMA
# 2               PENATA KELOLA LAYANAN KESEHATAN
# 3                        PERENCANA AHLI PERTAMA
# 4     PENGENDALI DAMPAK LINGKUNGAN AHLI PERTAMA
#
#                         UNIT PENEMPATAN YANG DILAMAR  \
# 0  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 1  PEMERINTAH DAERAH PROVINSI JAWA BARAT | SEKRET...
# 2  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 3  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# ...

# %%
df = df.drop(columns=['NO'])
df = df.rename(columns={'JENIS\rKELAMIN': 'GENDER'})
df.head()
# Out:
#    NOMOR REGISTRASI          NAMA PELAMAR  GENDER  \
# 0  6116111848928696   A AZFIKAR NUR AZHAR    Pria
# 1  6100118716575747  A FAISYAL RACHMAN JP    Pria
# 2  6100124600583863           A HIDAYANTI  Wanita
# 3  6100113674366924     A MAULANA MUKHSIN    Pria
# 4  6100110392034262     A MULQI FADILAH A    Pria
#
#                            JABATAN YANG DILAMAR  \
# 0                   PENGELOLA LAYANAN KESEHATAN
# 1  PENGELOLA PENGADAAN BARANG/JASA AHLI PERTAMA
# 2               PENATA KELOLA LAYANAN KESEHATAN
# 3                        PERENCANA AHLI PERTAMA
# 4     PENGENDALI DAMPAK LINGKUNGAN AHLI PERTAMA
#
#                         UNIT PENEMPATAN YANG DILAMAR  \
# 0  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 1  PEMERINTAH DAERAH PROVINSI JAWA BARAT | SEKRET...
# 2  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 3  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
# 4  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...
#
#                     KETERANGAN
# ...

# %%
mask = df["KETERANGAN"] == "Memenuhi Syarat / MS"

dinkes_ms = df[mask][df[mask]["UNIT PENEMPATAN YANG DILAMAR"].str.contains("DINAS KESEHATAN")]
dinkes_ms.head()
# Out:
#     NOMOR REGISTRASI                 NAMA PELAMAR  GENDER  \
# 0   6116111848928696          A AZFIKAR NUR AZHAR    Pria
# 2   6100124600583863                  A HIDAYANTI  Wanita
# 8   6100113504542621               A YOGHI DAMARA    Pria
# 10  6100110583465644  A. M. HUD NIBRAS FADHLULLAH    Pria
# 13  6100119734663986             A.BISRON ABRAHAM    Pria
#
#                JABATAN YANG DILAMAR  \
# 0       PENGELOLA LAYANAN KESEHATAN
# 2   PENATA KELOLA LAYANAN KESEHATAN
# 8   PENATA KELOLA LAYANAN KESEHATAN
# 10       OPERATOR LAYANAN KESEHATAN
# 13       PEREKAM MEDIS AHLI PERTAMA
#
#                          UNIT PENEMPATAN YANG DILAMAR            KETERANGAN
# 0   PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...  Memenuhi Syarat / MS
# 2   PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...  Memenuhi Syarat / MS
# 8   PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...  Memenuhi Syarat / MS
# 10  PEMERINTAH DAERAH PROVINSI JAWA BARAT | DINAS ...  Memenuhi Syarat / MS
# ...

# %%
dinkes_ms.to_excel("dinkes_ms.xlsx", index=False)
